# %% [markdown]
# # SOK-1006 V23
# ## Mappeoppgave 1 - Samfunnsøkonomisk analyse av en turistskatt
#
# ## Teller 50% av karakteren i faget.
#
# ### Innleveringsfrist fredag 24. mars 2023 kl 13.00 i Wiseflow
#
#
# ### 1. Bakgrunn
#
# I januar 2023 kunngjorde Nærings- og fiskeridepartementet at [Regjeringen vil gi kommuner mulighet til å innføre besøksbidrag](https://www.regjeringen.no/no/aktuelt/vurderer-destinasjoner-for-besoksbidrag/id2959885/?expand=factbox2959954). En mulig utforming av et besøksbidrag er i form av en turistskatt som overnattingssteder må kreve inn av besøkende per overnatting. Du er bedt om å skrive en utredning om de samfunnsøkonomiske konsekvenser av å innføre en slik turistskatt. Utredningen skal skrives på et slikt nivå at det er lett forståelig for næringsminister Jan Christian Vestre. (Han er utdannet jurist). Alle faguttrykk må forklares på en intuitiv måte, og figurer/tabeller må ha presise og gode forklaringer. Et godt eksempel på en slik utredning om et annet tema er [Utredning av utvalgte tiltak i det norske kraftmarkedet](https://www.regjeringen.no/contentassets/0f626d2e10ef48e591d2ceefce3546dc/afry_menon_oed_endelig-rapport.pdf) skrevet av AFRY og Menon til Olje- og Energidepartementet i september 2022. (Dette har vi brukt i forbindelse med forelesning 5).
#
#
# ### 2. Instruksjoner og oppgaver
#
# Mappeoppgaven besvares individuelt. Det er ikke tillatt å samarbeide med andre om utvikling av tekst og kode. Kode som du henter fra andre kilder må siteres - se [MIT retningslinjer](https://integrity.mit.edu/handbook/writing-code) som gir en god pekepinn. Det er ikke lov å bruke KI tjenester som ChatGPT til å skrive tekst eller kode.
#
# Dere skal levere to ting i Wiseflow:
# - en GitHub lenke til en Jupyter notatblokk (eller annen kildefil) som inneholder både Python-kode og tekst
# - en PDF eller HTML fil av Jupyter notatblokken
#
#
# Husk å merke alle filene med ditt kandidatnummer.
#
# Din utredning skal inneholde følgende elementer:
#
# *Kapittel 1 - Innledning*
#
# Gi litt bakgrunn i dette kapitlet.
#
# Du vil muligens komme inn på følgende:
# - Hva menes med en turistskatt på overnattinger?
# - Hva er begrunnelsen for dens innføring?
# - Hvor utbredt er dette tiltaket i andre land/byer?
# - Hvilke erfaringer har man gjort med en turistskatt?
#
# Til slutt vil kapitlet fortelle leseren om utredningens struktur.
#
# *Kapittel 2 - Turistnæringen i Norge*
#
# Her gir du leseren et overblikk over markedet som du skal analysere. Om du vil kan du begrense deg til Nord-Norge. Finn data som du laster ned og bruker til å tegne figurer for å gi en indikasjon på størrelsen og viktigheten  på dette markedet. For eksempel:
#
# - Hvordan har antall hotellovernattinger utviklet seg over tid?
# - Når på året kommer turister?
# - Hva er fordelingen av turister som ankommer via skip (cruise) og med fly, evt andre fremkomstmidler?
# - Hvordan er hotelløkonomien?
# - Hvor utbredt er private overnattinger gjennom Airbnb og andre plattformer?
# - Hvorfor kan disse momentene være viktig for din analyse?
#
# **Data**
#
# For at analysen din skal være mulig å replisere (dvs at jeg kan kjøre din analyse i en notatblokk) er det viktig at du ikke henter data- og bildefiler fra din egen PC. Jeg vil helst at dere laster data direkte fra nett ved hjelp av et API. Dere har brukt API-er i SOK-1004 mot SSB sine databaser. Dette er også mulig å gjøre i Python selvsagt, og SSB har laget en utmerket [veiledning](https://github.com/janbrus/ssb-api-python-examples/blob/master/jsonstatToPandas_funksjon.ipynb). Jeg har oppsummert dette i en Jupyter notatblokk som heter `api.ipynb` i mitt repo for dette kurset.
#
# **Datakilder**
#
# SSB lager et [satellittregnskap for turisme](https://www.ssb.no/nasjonalregnskap-og-konjunkturer/nasjonalregnskap/statistikk/satellittregnskap-for-turisme) som måler betydningen av reiselivet for norsk økonomi. Her vil dere finne det aller meste. [Kunnskapsbanken](https://telleren.kbnn.no/) har noen tall på reiseliv for Nord-Norge, inkludert Airbnb.
#
# **Ett eksempel** på hvordan man *kan* beskrive turisme er "Tourism in the Arctic", Derek J. Clark, Mikko Moilanen, Stein Østbye, kapittel 7 i  [The Economy of the North - ECONOR 2020](https://www.ssb.no/en/natur-og-miljo/artikler-og-publikasjoner/_attachment/454081?_ts=17bc94cfc98), SSB.
#
# *Kapittel 3 - Samfunnsøkonomiske effekter av en turistskatt*
#
# I dette kapitlet gjennomfører du analysen. Du kan vurdere å ta med følgende elementer:
#
# - Hva er formålet med å innføre en turistskatt på overnattinger?
# - Hvordan fungerer markedet for overnattinger uten en skatt?
# - Hvilke endringer forventer vi etter at skatten blir innført?
# - Hvilke effektivitets- og fordelingseffekter har dette tiltaket?
# - Hvor store effekter forventer vi, og hva er dette avhengig av?
# - Finnes det noen estimat på sentrale parameter (for eksempel priselastisiteten på etterspørsel etter overnattinger) som vi kan bruke for å konkretisere analysen?
# - En vurdering av hvorvidt formålet med tiltaket oppfylles.
#
# I kurset så langt har vi brukt ulike varianter av markedskrysset for å analysere forskjellige markeder, og dette blir verktøyet som brukes her også. Husk å gi en god forklaring av alle figurer som du lager i forbindelse med analysen. Dere har alt dere trenger! (Om du vil gå noe utover det som vi har snakket om i kurset så langt kan det være en idé å se på kapittel 13 i læreboka om "eksterne virkninger").
#
# *Kapittel 4 - Konklusjon*
#
# Her oppsummerer du kort dinne funn fra analysen, og råd til Nærings- og fiskeridepartementet.
#
#
# ### 3. Bedømmelse
#
# Formålet med oppgaven er å gi dere trening i å
#
# -   skrive godt og tydelig
#
# -   anvende data og lage figurer ved hjelp av Python-kode
#
# -   operasjonalisere mikroøkonomiske begrep og teori i en analyse
#
#
# Oppgaven bedømmes ut fra følgende kriterier:
#
# 1. evne til å gi kortfattede og presise definisjoner av grunnbegreper i mikroøkonomi
# 2. evne til å anvende mikroøkonomiske begrep og bruke disse til å analysere et marked
# 3. evne til å skrive konsist og presist for folk som ikke nødvendigvis er økonomer
# 4. at utredningen har god struktur, analysen henger sammen og at det går en rød tråd gjennom den
# 5. at forklaringene til figurene er presise og gode
# 6. at Python-koden dere bruker til å løse oppgaven er oversiktlig og godt dokumentert
#
#
# ### 4. Tilbakemelding underveis
#
# Dere vil få anledning til å levere et utkast av arbeidet til Derek én gang og få tilbakemelding. Utkastet sendes per e-post ([derek.clark\@uit.no](mailto:derek.clark@uit.no)) innen fredag 10. mars klokken 16.00. Besvarelser som sendes etter fristen blir ikke kommentert. NB. Derek tar ferie i uke 10 (6.-10.3).
#
# Lykke til!

# %%
import json
import pandas as pd
import requests
# pyjstat er biblioteket for å lese JSON-stat, 'pip install pyjstat' 
from pyjstat import pyjstat
import matplotlib.pyplot as plt
import sympy as sp
import numpy as np

# %%
# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/10638/"


### Spørring 1

apiQuery = {
  "query": [
    {
      "code": "KonsumInnd",
      "selection": {
        "filter": "item",
        "values": [
          "TOTK",
          "UTLK",
          "NOHT"
        ]
      }
    },
    {
      "code": "Reiseliv",
      "selection": {
        "filter": "item",
        "values": [
          "0",
          "01",
          "01.01",
          "01.02",
          "01.03",
          "01.04",
          "01.05",
          "01.06",
          "01.07",
          "01.08",
          "01.09",
          "01.10",
          "02"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "Priser"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %%
# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds

df, df_id, ds = apiToDataframe(postUrl, apiQuery)

# %%
postUrl = "https://data.ssb.no/api/v0/no/table/09266/"

apiQuery = {
  "query": [
    {
      "code": "Region",
      "selection": {
        "filter": "agg_single:Fylker2020",
        "values": [
          "30",
          "03",
          "34",
          "38",
          "42",
          "11",
          "46",
          "15",
          "50",
          "18",
          "54",
          "21"
        ]
      }
    },
    {
      "code": "Reiseliv",
      "selection": {
        "filter": "item",
        "values": [
          "SUMRL",
          "HR",
          "TR",
          "KU"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %%
def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res2 = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds2 = pyjstat.Dataset.read(res2.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df2 = ds2.write('dataframe')
    # deretter dataframe med koder
    df_id2 = ds2.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df2, df_id2, ds2

df2, df_id2, ds2 = apiToDataframe(postUrl, apiQuery)

# %%
postUrl = 'https://data.ssb.no/api/v0/no/table/11270/'

apiQuery = {
  "query": [
    {
      "code": "InnKvartering",
      "selection": {
        "filter": "item",
        "values": [
          "10"
        ]
      }
    },
    {
      "code": "Reisetype",
      "selection": {
        "filter": "item",
        "values": [
          "00",
          "01",
          "02"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %%
def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res3 = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds3 = pyjstat.Dataset.read(res3.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df3 = ds3.write('dataframe')
    # deretter dataframe med koder
    df_id3 = ds3.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df3, df_id3, ds3

df3, df_id3, ds3 = apiToDataframe(postUrl, apiQuery)

# %%
postUrl = 'https://data.ssb.no/api/v0/no/table/08403/'

apiQuery = {
  "query": [
    {
      "code": "Region",
      "selection": {
        "filter": "agg_single:Fylker2020",
        "values": [
          "18",
          "54"
        ]
      }
    },
    {
      "code": "HotellFormal",
      "selection": {
        "filter": "item",
        "values": [
          "03"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "Overnattinger"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "item",
        "values": [
          "2007M01",
          "2007M02",
          "2007M03",
          "2007M04",
          "2007M05",
          "2007M06",
          "2007M07",
          "2007M08",
          "2007M09",
          "2007M10",
          "2007M11",
          "2007M12",
          "2008M01",
          "2008M02",
          "2008M03",
          "2008M04",
          "2008M05",
          "2008M06",
          "2008M07",
          "2008M08",
          "2008M09",
          "2008M10",
          "2008M11",
          "2008M12",
          "2009M01",
          "2009M02",
          "2009M03",
          "2009M04",
          "2009M05",
          "2009M06",
          "2009M07",
          "2009M08",
          "2009M09",
          "2009M10",
          "2009M11",
          "2009M12",
          "2010M01",
          "2010M02",
          "2010M03",
          "2010M04",
          "2010M05",
          "2010M06",
          "2010M07",
          "2010M08",
          "2010M09",
          "2010M10",
          "2010M11",
          "2010M12",
          "2011M01",
          "2011M02",
          "2011M03",
          "2011M04",
          "2011M05",
          "2011M06",
          "2011M07",
          "2011M08",
          "2011M09",
          "2011M10",
          "2011M11",
          "2011M12",
          "2012M01",
          "2012M02",
          "2012M03",
          "2012M04",
          "2012M05",
          "2012M06",
          "2012M07",
          "2012M08",
          "2012M09",
          "2012M10",
          "2012M11",
          "2012M12",
          "2013M01",
          "2013M02",
          "2013M03",
          "2013M04",
          "2013M05",
          "2013M06",
          "2013M07",
          "2013M08",
          "2013M09",
          "2013M10",
          "2013M11",
          "2013M12",
          "2014M01",
          "2014M02",
          "2014M03",
          "2014M04",
          "2014M05",
          "2014M06",
          "2014M07",
          "2014M08",
          "2014M09",
          "2014M10",
          "2014M11",
          "2014M12",
          "2015M01",
          "2015M02",
          "2015M03",
          "2015M04",
          "2015M05",
          "2015M06",
          "2015M07",
          "2015M08",
          "2015M09",
          "2015M10",
          "2015M11",
          "2015M12",
          "2016M01",
          "2016M02",
          "2016M03",
          "2016M04",
          "2016M05",
          "2016M06",
          "2016M07",
          "2016M08",
          "2016M09",
          "2016M10",
          "2016M11",
          "2016M12",
          "2017M01",
          "2017M02",
          "2017M03",
          "2017M04",
          "2017M05",
          "2017M06",
          "2017M07",
          "2017M08",
          "2017M09",
          "2017M10",
          "2017M11",
          "2017M12",
          "2018M01",
          "2018M02",
          "2018M03",
          "2018M04",
          "2018M05",
          "2018M06",
          "2018M07",
          "2018M08",
          "2018M09",
          "2018M10",
          "2018M11",
          "2018M12",
          "2019M01",
          "2019M02",
          "2019M03",
          "2019M04",
          "2019M05",
          "2019M06",
          "2019M07",
          "2019M08",
          "2019M09",
          "2019M10",
          "2019M11",
          "2019M12",
          "2020M01",
          "2020M02",
          "2020M03",
          "2020M04",
          "2020M05",
          "2020M06",
          "2020M07",
          "2020M08",
          "2020M09",
          "2020M10",
          "2020M11",
          "2020M12",
          "2021M01",
          "2021M02",
          "2021M03",
          "2021M04",
          "2021M05",
          "2021M06",
          "2021M07",
          "2021M08",
          "2021M09",
          "2021M10",
          "2021M11",
          "2021M12",
          "2022M01",
          "2022M02",
          "2022M03",
          "2022M04",
          "2022M05",
          "2022M06",
          "2022M07",
          "2022M08",
          "2022M09",
          "2022M10",
          "2022M11",
          "2022M12",
          "2023M01"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %%
def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res4 = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds4 = pyjstat.Dataset.read(res4.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df4 = ds4.write('dataframe')
    # deretter dataframe med koder
    df_id4 = ds4.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df4, df_id4, ds4

df4, df_id4, ds4 = apiToDataframe(postUrl, apiQuery)

# %%
postUrl = 'https://data.ssb.no/api/v0/no/table/12897/'

apiQuery = {
  "query": [
    {
      "code": "Region",
      "selection": {
        "filter": "vs:Fylker2020",
        "values": [
          "18",
          "54"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "PrisRom"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "item",
        "values": [
          "2020M01",
          "2020M02",
          "2020M03",
          "2020M04",
          "2020M05",
          "2020M06",
          "2020M07",
          "2020M08",
          "2020M09",
          "2020M10",
          "2020M11",
          "2020M12",
          "2021M01",
          "2021M02",
          "2021M03",
          "2021M04",
          "2021M05",
          "2021M06",
          "2021M07",
          "2021M08",
          "2021M09",
          "2021M10",
          "2021M11",
          "2021M12",
          "2022M01",
          "2022M02",
          "2022M03",
          "2022M04",
          "2022M05",
          "2022M06",
          "2022M07",
          "2022M08",
          "2022M09",
          "2022M10",
          "2022M11",
          "2022M12"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}

# %%
def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res5 = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds5 = pyjstat.Dataset.read(res5.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df5 = ds5.write('dataframe')
    # deretter dataframe med koder
    df_id5 = ds5.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df5, df_id5, ds5

df5, df_id5, ds5 = apiToDataframe(postUrl, apiQuery)

# %% [markdown]
#  *Kapittel 1 - Innledning*
#
# Gi litt bakgrunn i dette kapitlet.
#
# Du vil muligens komme inn på følgende:
# - Hva menes med en turistskatt på overnattinger?
# - Hva er begrunnelsen for dens innføring?
# - Hvor utbredt er dette tiltaket i andre land/byer?
# - Hvilke erfaringer har man gjort med en turistskatt?
#
# Til slutt vil kapitlet fortelle leseren om utredningens struktur.

# %% [markdown]
# Turistskatter er en form for skattlegging som kreves av turister for å overnatte på hoteller, vandrerhjem og andre overnattingssteder i en bestemt region eller by. Hensikten med turistskatter er å generere inntekter som kan brukes til å finansiere turistrelaterte aktiviteter og infrastruktur, inkludert vedlikehold av turistattraksjoner, offentlige parker og toaletter, og støtte lokale arrangementer og festivaler som tiltrekker turister til regionen. Mens turistskatter er vanlige i mange land og byer over hele verden, er størrelsen og typen av turistskatt som kreves avhengig av landet eller byen.
#
# Formålet med turistskatter er å generere inntekter for lokale myndigheter som kan brukes til å finansiere turistrelaterte aktiviteter og infrastruktur. Dette inkluderer å opprettholde turistattraksjoner, offentlige parker og toaletter, og støtte lokale arrangementer og festivaler som tiltrekker turister til regionen. I tillegg kan turistskatter bidra til å dempe antall turister og forhindre overturisme, samt beskytte naturressurser og opprettholde bærekraftig turisme.
#
# Imidlertid er effektiviteten til turistskatter som en måte å finansiere turistrelatert infrastruktur og aktiviteter avhengig av en rekke faktorer, inkludert størrelsen og typen av turistskatt som kreves, bruken av inntektene som genereres, og den økonomiske situasjonen til regionen.
#
# Turistskatter er en vanlig måte å finansiere turistrelatert infrastruktur og aktiviteter på, og brukes av mange land og byer over hele verden. Mens turistskatter kan bidra til å generere inntekter for lokale myndigheter og opprettholde bærekraftig turisme, er effektiviteten avhengig av en rekke faktorer og kan møte motstand fra turister og lokale overnattingssteder.

# %% [markdown]
# kilde for eksempel på turistskatt i andre land: https://www.euronews.com/travel/2023/01/09/tourist-taxes-all-of-the-countries-you-will-have-to-pay-to-enter-in-2022
#
# kilde: https://www.nhoreiseliv.no/vi-mener/barekraftig-reiseliv/turistskatt/
# inspirasjon: https://www.nhoreiseliv.no/tall-og-fakta/tall-og-fakta-om-norsk-reiseliv/#sysselsetting
#
# NHO Reiseliv er den største arbeidsgiverorganisasjonen for reiselivet i Norge. De er imot turistskatten da de mener den kommer til å gjøre det mindre attraktivt å feriere i Norge da det allerede er blitt dyrere

# %% [markdown]
# *Kapittel 2 - Turistnæringen i Norge*
#
# Her gir du leseren et overblikk over markedet som du skal analysere. Om du vil kan du begrense deg til Nord-Norge. Finn data som du laster ned og bruker til å tegne figurer for å gi en indikasjon på størrelsen og viktigheten  på dette markedet. For eksempel:
#
# - Hvordan har antall hotellovernattinger utviklet seg over tid?
# - Når på året kommer turister?
# - Hva er fordelingen av turister som ankommer via skip (cruise) og med fly, evt andre fremkomstmidler?
# - Hvordan er hotelløkonomien?
# - Hvor utbredt er private overnattinger gjennom Airbnb og andre plattformer?
# - Hvorfor kan disse momentene være viktig for din analyse?

# %%
#hent nødvendig data fra df
df_grouped = df.groupby(['konsumentgruppe', 'år'])['value'].sum().reset_index()

# plot data
fig, ax = plt.subplots(figsize=(10, 6))
for label, group in df_grouped.groupby('konsumentgruppe'):
    ax.bar(group['år'], group['value'])

# Sett tittel, x- og y-akse, og legg til legend
ax.set_title('Konsumentutgifter til reiseliv i Norge')
ax.set_xlabel('År')
ax.set_ylabel('Verdi')
ax.legend(['Totalt', 'Utenlandske', 'Norske'])

# Display
plt.show()

# %% [markdown]
# Konsumentutgiftene i reiselivsindustrien i Norge har økt de siste årene, noe som kan indikere en økende interesse for å reise i eget land blant norske borgere. Samtidig viser tall fra Statistisk sentralbyrå (SSB) at det også har vært en økning i antall utenlandske turister som besøker Norge.
#
# En mulig årsak til økningen i konsumentutgifter kan være den økende interessen for å reise i eget land blant norske borgere. Dette kan skyldes økende bevissthet omkring miljø og bærekraft, samt økt tilgang til informasjon og markedsføring av norske reisemål. SSB rapporterer at antall norske overnattinger har økt med 7,4 prosent fra 2017 til 2018, mens utenlandske overnattinger har økt med 2,7 prosent i samme periode. Økningen i norske overnattinger kan indikere at nordmenn i større grad velger å feriere i eget land, og at dette kan være en faktor bak økningen i konsumentutgifter i reiselivsindustrien.
#
# En annen mulig årsak til økningen i konsumentutgifter i reiselivsindustrien kan være økt internasjonal turisme til Norge. SSB rapporterer at antall utenlandske overnattinger har økt med 25,4 prosent fra 2014 til 2018. Dette kan indikere at flere utenlandske turister velger å besøke Norge, og at dette fører til økt etterspørsel etter reiselivsrelaterte tjenester og produkter. Norge er kjent for sin vakre natur, fjorder og fjell, samt kulturelle attraksjoner som museer og festivaler. Økt markedsføring av disse unike trekkene ved Norge kan også ha bidratt til økt internasjonal turisme.

# %%
# Set up a figure with two columns
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

# First subplot: bar chart
verdier = df3['value'].values.tolist()
kategorier = df3['reisetype'].values.tolist()

# Plot the data
axs[0].bar(kategorier, verdier)

# Set title and axis labels
axs[0].set_title('Antall overnattinger på norske overnattingssteder')
axs[0].set_xlabel('Reisetype')
axs[0].set_ylabel('Antall overnattinger')

# Second subplot: line graph
df_plot = df3[['kvartal', 'value']]
df_plot = df_plot.set_index('kvartal')
df_plot = df_plot.sort_index()

ax = axs[1]
df_plot.plot(ax=ax)

# Set title and axis labels
ax.set_title('Antall gjestedøgn i Norge per kvartal')
ax.set_xlabel('Kvartal')
ax.set_ylabel('Gjestedøgn (millioner)')
ax.grid()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Velg de kolonnene i dataframen som du vil tegne et plott for
data = df5[['region', 'måned', 'value']]

# Grupper dataen etter region og beregn gjennomsnittsverdien for hver måned
gruppert = data.groupby(['region', 'måned']).mean().reset_index()

# Lag en pivot-tabell for å omforme dataen til et format som er egnet for tegning av plott
pivot = gruppert.pivot(index='måned', columns='region', values='value')

# Tegn dataene som et stolpeplott
pivot.plot(kind='bar', figsize=(12, 6))

# Legg til etiketter og tittel
plt.xlabel("Måned")
plt.ylabel("Gjennomsnittspris")
plt.title("Gjennomsnittspris etter region og måned")

# Vis plottet
plt.show()

# %%
# Velg kolonnene fra dataframen som du vil plottet
data = df4[['region', 'måned', 'value']]

# Konverter måned til år
data['år'] = data['måned'].apply(lambda x: x[:4])

# Gruppér dataen etter region og år og beregn gjennomsnittsverdien for hvert år
grouped = data.groupby(['region', 'år']).mean().reset_index()

# Filtrer dataen slik at bare årene 2020 til 2023 vises
filtered = grouped[(grouped['år'] >= '2020') & (grouped['år'] <= '2023')]

# Lag en pivottabell for å endre formen på dataen til en form som passer til plottet
pivot = filtered.pivot(index='år', columns='region', values='value')

# Plot dataen som et linjediagram
pivot.plot(kind='line', figsize=(12, 6))

# Legg til etiketter og tittel
plt.xlabel("År")
plt.ylabel("Gjennomsnittlig antall overnattinger")
plt.title("Gjennomsnittlig antall overnattinger etter region og år")

# Vis plottet
plt.show()
# Out:
# C:\Users\liner\AppData\Local\Temp\ipykernel_4312\3173872839.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['år'] = data['måned'].apply(lambda x: x[:4])
# C:\Users\liner\AppData\Local\Temp\ipykernel_4312\3173872839.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = data.groupby(['region', 'år']).mean().reset_index()

# %% [markdown]
# *Kapittel 3 - Samfunnsøkonomiske effekter av en turistskatt*
#
# I dette kapitlet gjennomfører du analysen. Du kan vurdere å ta med følgende elementer:
#
# - Hva er formålet med å innføre en turistskatt på overnattinger?
# - Hvordan fungerer markedet for overnattinger uten en skatt?
# - Hvilke endringer forventer vi etter at skatten blir innført?
# - Hvilke effektivitets- og fordelingseffekter har dette tiltaket?
# - Hvor store effekter forventer vi, og hva er dette avhengig av?
# - Finnes det noen estimat på sentrale parameter (for eksempel priselastisiteten på etterspørsel etter overnattinger) som vi kan bruke for å konkretisere analysen?
# - En vurdering av hvorvidt formålet med tiltaket oppfylles.

# %% [markdown]
# Turistskatt er en type skatt som innføres på overnattinger og har flere formål. Én av hovedhensiktene er å skaffe inntekter som kan brukes til å finansiere offentlige tjenester og tiltak som turister drar nytte av. Dette kan omfatte vedlikehold av offentlige bygninger og fasiliteter, turistinformasjon, kulturarrangementer og infrastruktur.
#
# En annen grunn til å innføre turistskatt er å redusere miljøbelastningen som turismen kan medføre. Ved å øke kostnadene for overnattinger, kan turistskatt motivere turister til å velge mer bærekraftige transportmidler og overnattingssteder og oppmuntre til en mer ansvarlig holdning til miljøet.
#
# Markedet for overnattinger uten en skatt fungerer på samme måte som ethvert annet marked. Turister som søker overnatting, velger mellom et bredt utvalg av overnattingssteder som hoteller, moteller, bed and breakfasts, leiligheter og private utleieenheter. Disse overnattingsstedene konkurrerer om turistenes gunst ved å tilby ulike priser, fasiliteter og beliggenhet.
#
# Innføringen av en turistskatt på overnattinger kan ha flere potensielle konsekvenser for markedet for overnattinger og turisme generelt. En økning i prisen på overnattinger som følge av skatten kan føre til at noen turister velger billigere alternativer eller reiser til andre destinasjoner, og redusere etterspørselen etter overnattinger. Dette kan igjen føre til et overskudd av overnattingskapasitet og redusert lønnsomhet for overnattingssteder.
#
# Samtidig kan turistskatten gi lokale myndigheter mulighet til å øke sine inntekter, som kan brukes til å finansiere tiltak som gagner både turister og lokalbefolkningen. Dette kan inkludere investeringer i turistattraksjoner, oppgradering av infrastruktur og bedre ivaretakelse av miljøet. På lengre sikt kan turistskatten også bidra til å redusere miljøbelastningen ved turismen og skape et mer bærekraftig og ansvarlig forhold mellom turister og lokalbefolkningen.
#
# Det er imidlertid viktig å være oppmerksom på potensielle negative konsekvenser av turistskatten. Økningen i prisen på overnattinger kan føre til at noen turister velger å reise til andre destinasjoner eller velger billigere overnattingssteder, og dermed redusere etterspørselen etter overnattinger. Dette kan igjen føre til et overskudd av overnattingskapasitet og redusert lønnsomhet for overnattingssteder, spesielt hvis turistskatten er høy.
#
# På lengre sikt kan imidlertid turistskatten bidra til å redusere de negative konsekvensene av overturisme, som overfylte gater, støy og annen ulempe som turismen kan medføre. Turistskatten kan også føre til en mer balansert og rettferdig fordeling av fordelene og ulempene ved turisme, og bidra til å begrense de negative konsekvensene av overturisme. Samlet sett kan en turistskatt på overnattinger ha både positive og negative effekter på markedet for overnattinger og turisme generelt, og det er viktig å veie fordeler og ulemper nøye når man vurderer å innføre en slik skatt.
#
# Effektivitetseffekten kan ses i form av en mer effektiv utnyttelse av overnattingskapasiteten på destinasjonen. Med en ekstra avgift på overnattinger vil prisen for turistene øke, noe som kan føre til at etterspørselen etter overnattinger synker. Dette kan igjen føre til en reduksjon i antall ledige rom og en mer effektiv utnyttelse av overnattingskapasiteten. Skatteinntektene fra turistskatten kan brukes til å finansiere tiltak som gagner både turister og lokalbefolkningen, som for eksempel vedlikehold av offentlige bygninger og fasiliteter, turistinformasjon og kulturarrangementer. Dette kan bidra til å øke effektiviteten i turistindustrien.
#
# Fordelingseffekten kan ses i form av en mer rettferdig fordeling av kostnadene og fordelene ved turisme. Turister som tidligere ikke bidro med skatteinntekter vil nå belastes med en ekstra avgift, noe som kan føre til at de som reiser oftere eller velger mer luksuriøse overnattingssteder, bidrar mer til samfunnet. Dette kan bidra til en mer rettferdig fordeling av kostnadene ved turisme. Samtidig kan skatteinntektene brukes til å finansiere tiltak som gagner både turister og lokalbefolkningen, som for eksempel investeringer i turistattraksjoner, oppgradering av infrastruktur og bedre ivaretakelse av miljøet. Dette kan bidra til en mer balansert fordeling av fordelene ved turisme og redusere ulempene ved overturisme.
#
# En turistskatt kan ha betydelige effekter på etterspørselen etter overnattinger, og dette avhenger av flere faktorer. For det første vil populariteten til destinasjonen spille en rolle i hvor mye en skatt kan påvirke etterspørselen etter overnattinger. Populære destinasjoner kan tåle høyere skatter, mens mindre populære destinasjoner kan være mer sårbare for økningen i pris. Videre vil størrelsen på skatten og hvordan skatteinntektene brukes også påvirke effektene. Hvis skatten er høy og brukes til tiltak som ikke gagner turister, kan det føre til en betydelig reduksjon i etterspørselen etter overnattinger, spesielt blant prisfølsomme turister. Men en moderat skatt som brukes til tiltak som gagner både turister og lokalbefolkningen, kan ha mindre negative effekter på etterspørselen etter overnattinger.
#
# Det er også viktig å vurdere hvordan skatteinntektene brukes. Hvis skatteinntektene brukes til tiltak som forbedrer turistopplevelsen og ivaretar miljøet, kan det bidra til å øke destinasjonens attraktivitet og dermed motvirke de negative effektene av en turistskatt. På samme måte kan skatteinntektene også brukes til å redusere andre skatter eller finansiere andre offentlige tjenester, som kan ha positive effekter på både turister og lokalbefolkningen.

# %%
# 2022 til 2023 ## q2

natt_troms_22 = df4.iloc[373:385]
natt_nordland_22 = df4.iloc[180:193]
q2 = natt_nordland_22['value'].sum()+natt_troms_22['value'].sum()

nordland_22 = df5.iloc[24:36]
troms_22 = df5.iloc[60:72]
p2 = (troms_22['value'].sum()/12) + (nordland_22['value'].sum()/12)

# %%
# 2020 til 2021 ## q1
natt_troms_20 = df4.iloc[349:361]
natt_nordland_20 = df4.iloc[156:168]
q1 = natt_nordland_20['value'].sum()+natt_troms_20['value'].sum()

nordland_20 = df5.iloc[0:12]
troms_20 = df5.iloc[36:48]
p1= (troms_20['value'].sum()/12) + (nordland_20['value'].sum()/12)

# %%
print(q1)
print(q2)
print(p1)
print(p2)
# Out:
# 1066870
# 1686657
# 1908.6666666666665
# 2109.25

# %%
elastisitet = (q2 - q1) / ((q2 + q1) / 2) / (p2 - p1) / ((p2 + p1) / 2)
elastisitet
# Out:
# 1.1171650624771715e-06

# %% [markdown]
# Priselastisiteten av hotellrom sier noe om hvordan etterspørselen etter hotellrom påvirkes av endringer i pris. Hvis priselastisiteten er positiv, betyr det at etterspørselen etter hotellrom øker når prisen stiger, og reduseres når prisen synker. Dette indikerer at hotellrom er et inferiørt produkt, og folk vil endre sitt kjøp avhengig av prisendringer.
#
# På den annen side, hvis priselastisiteten er nær null, betyr det at endringer i pris har liten eller ingen innvirkning på etterspørselen etter hotellrom. Dette indikerer at hotellrom er et veldig uelastisk produkt, og folk vil kjøpe omtrent like mye uansett hva prisen er.

# %%
#define functions for demand and supply
def demand(p):
    return (500-p)/3.2
def supply(p, t):
    return ((100+p)/4.3) + t

p,t = sp.symbols('p t', real=True, positive=True)
equ = sp.Eq(demand(p), supply(p,t))

x_eq=sp.solve(equ, p)
print(x_eq[0])

p_eq=demand(x_eq[0])

p,t = sp.symbols('p t', real=True, positive=True)
equ = sp.Eq(demand(p), supply(p,t))
producer=sp.integrate(p_eq-supply(p, t),(p,0,x_eq))
consumer=sp.integrate(demand(p)-p_eq,(p,0,x_eq))
welfare=(sp.integrate(demand(p)-supply(p, t),(p,0,x_eq)))
avprov = sp.integrate(t, (p, 0, x_eq))

x_num=np.linspace(0.1,500,100)
equ_t0 = sp.Eq(demand(p),supply(p, 0))

x_eq_t0 = sp.solve(equ_t0,p)
x_eq_t0 = float(x_eq_t0[0])
p_eq_t0=demand(x_eq_t0)

x_num=np.linspace(0.1,500,100)

equ_t4 = sp.Eq(demand(p),supply(p, 4))

x_eq_t4 = sp.solve(equ_t4,p)
x_eq_t4 = float(x_eq_t4[0])

p_eq_t4=demand(x_eq_t4)

def create_ax2():
                fig, ax = plt.subplots()
                ax.set_ylabel('Pris', loc='top')
                ax.set_xlabel('Mengde', loc='right')
                ax.set(xlim=(150,250))
                ax.set(ylim=(60,110))
                ax.spines['top'].set_color('none')
                ax.spines['right'].set_color('none')
                
                return fig, ax

fig, ax = create_ax2()

ax.plot(x_num, demand(x_num), label='Etterspørsel')
ax.plot(x_num, supply(x_num, 0), label='Tilbud u/avgift')
ax.plot(x_num, supply(x_num, 4), label='Tilbud m/avgift')

ax.set_title('Eksempel på hvordan ett marked vil bli påvirket av en avgift')

q2 = np.linspace(0,x_eq_t4,100)
q3 = np.linspace(x_eq_t0,x_eq_t4,100)

#vlines
ax.vlines(x_eq_t4, 0, demand(x_eq_t4), color = 'black',linestyle = 'dashed', alpha=0.3)
ax.vlines(x_eq_t0, 0, demand(x_eq_t0), color = 'black',linestyle = 'dashed', alpha=0.3)

#fill between
ax.fill_between(q2,p_eq_t4,demand(q2), color = 'green',alpha = 0.3,label='Konsumentoverskudd')
ax.fill_between(q2,supply(q2, 0),p_eq_t4-4, color = 'red',alpha = 0.3,label='Produsentoverskudd')
ax.fill_between(q2,p_eq_t4,p_eq_t4-4, color = 'yellow', alpha = 0.3,label='Skatteproveny')
ax.fill_between(q3,supply(q3, 0),demand(q3), color = 'blue',alpha = 0.3,label='Dødvektstap')

#legende
ax.legend(bbox_to_anchor=(1.5,0.6))
plt.show()
# Out:
# 244.0 - 1.83466666666667*t
